# %%
import pandas as pd

# %%
model_A = pd.read_csv('submission_v4.csv', usecols=['is_duplicate'])
model_B = pd.read_csv('20170511_0046_1.csv', usecols=['is_duplicate'])
merged = pd.concat([model_A, model_B], axis=1)

# %%
final_model = pd.DataFrame()
final_model['is_duplicate'] = merged.mean(axis=1)
final_model.to_csv(
    path_or_buf='final.csv',
    index_label='test_id'
)

# %%
final_model
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>is_duplicate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.136830</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.286826</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.424950</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.217864</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.432536</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>0.184026</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>0.414682</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>0.751075</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>0.378214</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>0.085058</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>0.518560</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>0.114295</td>
#     </tr>
# ...
